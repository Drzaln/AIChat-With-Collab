# %% [markdown]
# # 🚀 Colab LLM Server · Api Code CLI Bridge
#
# **Stack:** `Ollama` → `LiteLLM Proxy` → `Cloudflare Tunnel`
# **Model default:** Hermes-4-14B-BF16-abliterated-i1-GGUF (IQ4_XS, ~7 GB)
# **GPU required:** Nvidia T4 — aktifkan di `Runtime → Change runtime type → T4 GPU`
#
# ---
#
# ## Cara Kerja
#
# | Komponen | Fungsi |
# |---|---|
# | **Ollama** | Menjalankan 14B LLM di T4 GPU (16 GB VRAM) |
# | **LiteLLM Proxy** | Menerjemahkan format API → Ollama API |
# | **Cloudflare Tunnel** | Membuat URL publik HTTPS tanpa butuh akun |
#
# ## Langkah Penggunaan
#
# 1. ✅ Aktifkan GPU T4: `Runtime → Change runtime type → T4 GPU`
# 2. ▶️  Jalankan cell di bawah ini dan tunggu (~15 menit pada run pertama)
# 3. 📋 Salin perintah `export` dari output ke terminal lokal kamu
# 4. 🖥️ masukan url dan apikey ke env, local akan menggunakan LLM di Colab!
#
# ## Pilihan Model
#
# | Model | Keunggulan |
# |---|---|
# | `EVA-abliterated-TIES-Qwen2.5-14B-i1-GGUF:Q6_K` ⭐ | fastest, no refusals |
# | `Hermes-4-14B-BF16-abliterated-i1-GGUF Q6_K` | Reasoning lebih baik, general purpose |
#
# ---
#
# > ⚠️ **Penting:** Biarkan cell ini tetap running saat menggunakan local LLM
# > URL Cloudflare bersifat sementara dan berubah setiap restart.

# %%
import subprocess, time, os, re, requests

# ⚙─ CONFIGURATION ───────────────────────────────
# ▸ Pilih model (uncomment salah satu):

# f947 REKOMENDASI: Coding specialist, abliterated (no refusals)
#MODEL = "hf.co/bartowski/Qwen2.5-Coder-14B-Instruct-abliterated-GGUF:Q6_K"

#MODEL = "hf.co/mradermacher/Hermes-4-14B-BF16-abliterated-i1-GGUF:IQ4_XS"
#MODEL = "hf.co/mradermacher/Hermes-4-14B-BF16-abliterated-i1-GGUF:Q6_K"
#MODEL = "hf.co/bartowski/nbeerbower_Dumpling-Qwen2.5-14B-GGUF:Q6_K"
MODEL = "hf.co/mradermacher/EVA-abliterated-TIES-Qwen2.5-14B-i1-GGUF:Q6_K"

# f948 Qwen3 generasi terbaru, reasoning lebih baik
# MODEL = "hf.co/richardyoung/Qwen3-14B-abliterated-GGUF:Q6_K"

# f949 DeepSeek-R1 distilled — chain-of-thought terbaik untuk bug kompleks
# MODEL = "hf.co/unsloth/DeepSeek-R1-Distill-Qwen-14B-GGUF:Q6_K"

OLLAMA_PORT = 11434
PROXY_PORT  = 4000
API_KEY     = "sk-colab-local"
# ────────────────────────────────────────────────────────────


# ── Utility Functions ───────────────────────────────────────

def sh(cmd, check=True, quiet=False, capture=False):
    """Run shell command."""
    kw = dict(shell=True, check=check)
    if capture:
        kw.update(capture_output=True, text=True)
    elif quiet:
        kw.update(stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    return subprocess.run(cmd, **kw)

def bg(cmd, log=None):
    """Run shell command in background."""
    out = open(log, "w") if log else subprocess.DEVNULL
    return subprocess.Popen(cmd, shell=True, stdout=out, stderr=subprocess.STDOUT)

def wait_http(url, timeout=60, name=""):
    """Poll URL until it responds (< 500 status)."""
    for i in range(timeout):
        try:
            if requests.get(url, timeout=2).status_code < 500:
                print(f"  ✅ {name} is ready")
                return True
        except:
            pass
        if i > 0 and i % 15 == 14:
            print(f"  ⌛ Still waiting for {name}… ({i+1}s)")
        time.sleep(1)
    print(f"  ⚠️  {name} not confirmed after {timeout}s — continuing")
    return False

def section(n, total, title):
    bar = "─" * 64
    print(f"\n{bar}\n  [{n}/{total}]  {title}\n{bar}")


# ── BANNER ────────────────────────────────────────────────
print("╔══════════════════════════════════════════════════════════════╗")
print("║   f680  Colab LLM Server · Api Code CLI Bridge             ║")
print("║   Stack: Ollama → LiteLLM Proxy → Cloudflare Tunnel         ║")
print("╚══════════════════════════════════════════════════════════════╝")

# GPU check
r = sh("nvidia-smi --query-gpu=name,memory.total --format=csv,noheader",
       check=False, capture=True)
if r.returncode == 0:
    print(f"\n  f3ae  GPU    : {r.stdout.strip()}")
else:
    print("\n  ⚠️  No GPU — aktifkan T4: Runtime → Change runtime type → T4 GPU")
print(f"  f916  Model  : {MODEL}\n")


# ── 1. INSTALL OLLAMA BINARY ────────────────────────────
section(1, 5, "Install Ollama Binary (via Custom GitHub Link)")

# 1. Pastikan zstd terinstal agar bisa mengekstrak file .tar.zst
sh("apt-get update -qq && apt-get install -y -qq zstd", check=False)

# 2. Bersihkan file sisa sebelumnya agar tidak bentrok
sh("rm -rf ollama.tar.zst /usr/local/bin/ollama /usr/bin/ollama", check=False)

# 3. Unduh dari link spesifik yang kamu berikan
url = "https://github.com/ollama/ollama/releases/download/v0.30.10/ollama-linux-amd64.tar.zst"
print(f"  ⌛ Mengunduh Ollama dari {url} ...")
sh(f"wget -q {url} -O ollama.tar.zst")

# 4. Ekstrak file tar.zst langsung ke direktori /usr
# (Ollama memaketkannya dengan folder bin/ dan lib/ di dalamnya)
sh("tar -C /usr -xaf ollama.tar.zst")

# 5. Cek apakah instalasi berhasil
r = sh("ollama --version", capture=True, check=False)
if r.returncode == 0:
    print(f"  ✅ Ollama installed: {r.stdout.strip()}")
else:
    print("  ⚠️ Gagal diekstrak. (Catatan: Jika error, pastikan tidak ada typo pada v0.30.10 di link tersebut)")


# ── 2. START OLLAMA SERVER ────────────────────────────
section(2, 5, "Start Ollama Server")
ollama_proc = bg(
    "OLLAMA_HOST=0.0.0.0:11434 OLLAMA_ORIGINS='*' ollama serve",
    "/tmp/ollama.log"
)
time.sleep(3)
wait_http(f"http://localhost:{OLLAMA_PORT}", 30, "Ollama")


# ── 3. PULL MODEL ──────────────────────────────
section(3, 5, "Pull Model from HuggingFace (~7 GB)")
print(f"  ⌛ First run takes 10-20 min depending on Colab speed…\n")
sh(f"ollama pull {MODEL}")

# Alias ke nama pendek agar LiteLLM bisa referensikan dengan mudah
with open("/tmp/Modelfile", "w") as f:
    f.write(f"FROM {MODEL}\n")
result = sh("ollama create character -f /tmp/Modelfile", check=False, capture=True)
if result.returncode == 0:
    print(f"\n  ✅ Model ready, aliased as 'character'")
else:
    # Fallback: gunakan nama lengkap langsung di LiteLLM
    print(f"\n  ℹ️  Alias tidak dibuat, akan gunakan nama model langsung")


# ── 4. LITELLM PROXY (Anthropic API → Ollama) ───────────────
section(4, 5, "LiteLLM: API → Ollama Bridge")
print("  Installing litellm…")
sh("pip install -q 'litellm[proxy]'")

# Tentukan nama model Ollama yang akan dipakai
# Jika alias 'coder' berhasil dibuat, pakai itu; jika tidak, pakai nama asli HF
ollama_model_name = "character" if result.returncode == 0 else MODEL.replace("hf.co/", "hf.co/")

# Map semua nama model
LLMs_models = [
    "character1",
    MODEL,
]
entries = "\n".join(
    f"  - model_name: {n}\n"
    f"    litellm_params:\n"
    f"      model: ollama/{ollama_model_name}\n"
    f"      api_base: http://localhost:{OLLAMA_PORT}"
    for n in LLMs_models
)
litellm_yaml = f"""
model_list:
{entries}

litellm_settings:
  drop_params: true
  set_verbose: false

general_settings:
  master_key: "{API_KEY}"
"""
with open("/tmp/litellm.yaml", "w") as f:
    f.write(litellm_yaml)

litellm_proc = bg(
    f"litellm --config /tmp/litellm.yaml --port {PROXY_PORT} --host 0.0.0.0",
    "/tmp/litellm.log"
)
time.sleep(6)
wait_http(f"http://localhost:{PROXY_PORT}/health", 45, "LiteLLM proxy")


# ── 5. CLOUDFLARE TUNNEL ────────────────────────────
section(5, 5, "Cloudflare Tunnel → Public HTTPS URL")
sh(
    "wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/"
    "cloudflared-linux-amd64 -O /usr/local/bin/cloudflared "
    "&& chmod +x /usr/local/bin/cloudflared"
)
cf_proc = bg(
    f"cloudflared tunnel --url http://localhost:{PROXY_PORT}",
    "/tmp/cloudflared.log"
)

print("  ⌛ Waiting for public URL…")
tunnel_url = None
for _ in range(90):
    time.sleep(1)
    try:
        text = open("/tmp/cloudflared.log").read()
        m = re.search(r"https://[a-z0-9\-]+\.trycloudflare\.com", text)
        if m:
            tunnel_url = m.group(0)
            break
    except:
        pass


# ── READY ────────────────────────────────────────────
print()
print("╔══════════════════════════════════════════════════════════════╗")
if tunnel_url:
    print("║   ✅  SERVER IS READY                                        ║")
else:
    print("║   ⚠️   SERVER STARTED (no tunnel URL found)                  ║")
print("╚══════════════════════════════════════════════════════════════╝")

if tunnel_url:
    print(f"""
  f517  URL     : {tunnel_url}
  f916  Model   : {MODEL}
  f511  API Key : {API_KEY}

  ╔══════════════════════════════════════════════════════════════╗
  ║   Paste di ENV LOKAL kamu untuk pakai Custom LLMs      :     ║
  ╠══════════════════════════════════════════════════════════════╣
  ║                                                              ║
  ║   BASE_URL="{tunnel_url}"
  ║   API_KEY="{API_KEY}"
  ║                                                              ║
  ║                                                              ║
  ╠══════════════════════════════════════════════════════════════╣
  ║   One-liner version:                                         ║
  ╠══════════════════════════════════════════════════════════════╣
  ║                                                              ║
  ║   BASE_URL="{tunnel_url}"
  ║   API_KEY="{API_KEY}"                                        ║
  ║                                                              ║
  ╚══════════════════════════════════════════════════════════════╝

  ⚠️  PENTING:
  • Biarkan cell ini tetap RUNNING saat menggunakan custom LLMs
  • URL bersifat SEMENTARA — berubah setiap kali restart
  • Colab gratis timeout ~90 menit idle
  • Request pertama butuh 30-60 detik (model warm-up)
""")
else:
    print(f"\n  ⚠️  Tidak dapat mendapatkan URL tunnel.")
    print(f"     Cek log: !cat /tmp/cloudflared.log")
    print(f"     LiteLLM proxy lokal: http://localhost:{PROXY_PORT}")

print("  ⌛ Cell berjalan terus menerus. Stop cell untuk shutdown.\n")


# ── KEEP ALIVE (Heartbeat) ─────────────────────────────
tick = 0
try:
    while True:
        time.sleep(60)
        tick += 1
        ts = time.strftime("%H:%M:%S")
        try:
            requests.get(f"http://localhost:{PROXY_PORT}/health", timeout=5)
            status = "f49a healthy"
        except:
            status = "⚠️  unreachable"
        print(f"  [{ts}] heartbeat #{tick:04d} | proxy {status} | {tunnel_url or 'no tunnel'}")
except KeyboardInterrupt:
    print("\n  ⛔ Shutting down all services…")
    for proc in [cf_proc, litellm_proc, ollama_proc]:
        try:
            proc.terminate()
        except:
            pass
    print("  ✅ All services stopped.")
# Out:
# ╔══════════════════════════════════════════════════════════════╗
# ║   f680  Colab LLM Server · Api Code CLI Bridge             ║
# ║   Stack: Ollama → LiteLLM Proxy → Cloudflare Tunnel         ║
# ╚══════════════════════════════════════════════════════════════╝
#
#   f3ae  GPU    : Tesla T4, 15360 MiB
#   f916  Model  : hf.co/mradermacher/EVA-abliterated-TIES-Qwen2.5-14B-i1-GGUF:Q6_K
#
#
# ────────────────────────────────────────────────────────────────
#   [1/5]  Install Ollama Binary (via Custom GitHub Link)
# ────────────────────────────────────────────────────────────────
#   ⌛ Mengunduh Ollama dari https://github.com/ollama/ollama/releases/download/v0.30.10/ollama-linux-amd64.tar.zst ...
#   ✅ Ollama installed: Warning: could not connect to a running Ollama instance
# Warning: client version is 0.30.10
#
# ────────────────────────────────────────────────────────────────
#   [2/5]  Start Ollama Server
# ────────────────────────────────────────────────────────────────
#   ✅ Ollama is ready
#
# ────────────────────────────────────────────────────────────────
#   [3/5]  Pull Model from HuggingFace (~7 GB)
# ────────────────────────────────────────────────────────────────
#   ⌛ First run takes 10-20 min depending on Colab speed…
#
#
#   ✅ Model ready, aliased as 'character'
#
# ────────────────────────────────────────────────────────────────
#   [4/5]  LiteLLM: API → Ollama Bridge
# ────────────────────────────────────────────────────────────────
#   Installing litellm…
#   ⌛ Still waiting for LiteLLM proxy… (15s)
#   ⌛ Still waiting for LiteLLM proxy… (30s)
#   ⌛ Still waiting for LiteLLM proxy… (45s)
#   ⚠️  LiteLLM proxy not confirmed after 45s — continuing
#
# ────────────────────────────────────────────────────────────────
#   [5/5]  Cloudflare Tunnel → Public HTTPS URL
# ────────────────────────────────────────────────────────────────
#   ⌛ Waiting for public URL…
#
# ╔══════════════════════════════════════════════════════════════╗
# ║   ✅  SERVER IS READY                                        ║
# ╚══════════════════════════════════════════════════════════════╝
#
#   f517  URL     : https://rebates-thinkpad-attached-ate.trycloudflare.com
#   f916  Model   : hf.co/mradermacher/EVA-abliterated-TIES-Qwen2.5-14B-i1-GGUF:Q6_K
#   f511  API Key : sk-colab-local
#
#   ╔══════════════════════════════════════════════════════════════╗
#   ║   Paste di ENV LOKAL kamu untuk pakai Custom LLMs      :     ║
#   ╠══════════════════════════════════════════════════════════════╣
#   ║                                                              ║
#   ║   BASE_URL="https://rebates-thinkpad-attached-ate.trycloudflare.com"
#   ║   API_KEY="sk-colab-local"
#   ║                                                              ║
#   ║                                                              ║
#   ╠══════════════════════════════════════════════════════════════╣
#   ║   One-liner version:                                         ║
#   ╠══════════════════════════════════════════════════════════════╣
#   ║                                                              ║
#   ║   BASE_URL="https://rebates-thinkpad-attached-ate.trycloudflare.com"
#   ║   API_KEY="sk-colab-local"                                        ║
#   ║                                                              ║
#   ╚══════════════════════════════════════════════════════════════╝
#
#   ⚠️  PENTING:
#   • Biarkan cell ini tetap RUNNING saat menggunakan custom LLMs
#   • URL bersifat SEMENTARA — berubah setiap kali restart
#   • Colab gratis timeout ~90 menit idle
#   • Request pertama butuh 30-60 detik (model warm-up)
#
#   ⌛ Cell berjalan terus menerus. Stop cell untuk shutdown.
#
#   [16:31:27] heartbeat #0001 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [16:32:27] heartbeat #0002 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [16:33:27] heartbeat #0003 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [16:34:27] heartbeat #0004 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [16:35:27] heartbeat #0005 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [16:36:27] heartbeat #0006 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [16:37:27] heartbeat #0007 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [16:38:27] heartbeat #0008 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [16:39:27] heartbeat #0009 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [16:40:27] heartbeat #0010 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [16:41:27] heartbeat #0011 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [16:42:27] heartbeat #0012 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [16:43:27] heartbeat #0013 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [16:44:28] heartbeat #0014 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [16:45:28] heartbeat #0015 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [16:46:28] heartbeat #0016 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [16:47:28] heartbeat #0017 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [16:48:28] heartbeat #0018 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [16:49:28] heartbeat #0019 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [16:50:28] heartbeat #0020 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [16:51:28] heartbeat #0021 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [16:52:28] heartbeat #0022 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [16:53:28] heartbeat #0023 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [16:54:28] heartbeat #0024 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [16:55:28] heartbeat #0025 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [16:56:28] heartbeat #0026 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [16:57:28] heartbeat #0027 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [16:58:28] heartbeat #0028 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [16:59:28] heartbeat #0029 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:00:28] heartbeat #0030 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:01:28] heartbeat #0031 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:02:28] heartbeat #0032 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:03:28] heartbeat #0033 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:04:28] heartbeat #0034 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:05:28] heartbeat #0035 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:06:28] heartbeat #0036 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:07:28] heartbeat #0037 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:08:28] heartbeat #0038 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:09:28] heartbeat #0039 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:10:28] heartbeat #0040 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:11:28] heartbeat #0041 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:12:28] heartbeat #0042 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:13:28] heartbeat #0043 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:14:29] heartbeat #0044 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:15:29] heartbeat #0045 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:16:29] heartbeat #0046 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:17:29] heartbeat #0047 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:18:29] heartbeat #0048 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:19:29] heartbeat #0049 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:20:29] heartbeat #0050 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:21:29] heartbeat #0051 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:22:29] heartbeat #0052 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:23:29] heartbeat #0053 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:24:29] heartbeat #0054 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:25:29] heartbeat #0055 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:26:29] heartbeat #0056 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:27:29] heartbeat #0057 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:28:29] heartbeat #0058 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:29:29] heartbeat #0059 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:30:29] heartbeat #0060 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:31:29] heartbeat #0061 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:32:29] heartbeat #0062 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:33:29] heartbeat #0063 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:34:29] heartbeat #0064 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:35:29] heartbeat #0065 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:36:29] heartbeat #0066 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:37:29] heartbeat #0067 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:38:29] heartbeat #0068 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:39:29] heartbeat #0069 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:40:29] heartbeat #0070 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:41:29] heartbeat #0071 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:42:29] heartbeat #0072 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:43:29] heartbeat #0073 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:44:29] heartbeat #0074 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:45:29] heartbeat #0075 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:46:29] heartbeat #0076 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:47:29] heartbeat #0077 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:48:29] heartbeat #0078 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:49:30] heartbeat #0079 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:50:30] heartbeat #0080 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:51:30] heartbeat #0081 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:52:30] heartbeat #0082 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:53:30] heartbeat #0083 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:54:30] heartbeat #0084 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:55:30] heartbeat #0085 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:56:30] heartbeat #0086 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:57:30] heartbeat #0087 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:58:30] heartbeat #0088 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [17:59:30] heartbeat #0089 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:00:30] heartbeat #0090 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:01:30] heartbeat #0091 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:02:30] heartbeat #0092 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:03:30] heartbeat #0093 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:04:30] heartbeat #0094 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:05:30] heartbeat #0095 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:06:30] heartbeat #0096 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:07:30] heartbeat #0097 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:08:30] heartbeat #0098 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:09:30] heartbeat #0099 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:10:30] heartbeat #0100 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:11:30] heartbeat #0101 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:12:30] heartbeat #0102 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:13:30] heartbeat #0103 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:14:30] heartbeat #0104 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:15:30] heartbeat #0105 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:16:30] heartbeat #0106 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:17:30] heartbeat #0107 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:18:30] heartbeat #0108 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:19:30] heartbeat #0109 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:20:31] heartbeat #0110 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:21:31] heartbeat #0111 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:22:31] heartbeat #0112 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:23:31] heartbeat #0113 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:24:31] heartbeat #0114 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:25:31] heartbeat #0115 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:26:31] heartbeat #0116 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:27:31] heartbeat #0117 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:28:31] heartbeat #0118 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:29:31] heartbeat #0119 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:30:31] heartbeat #0120 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:31:31] heartbeat #0121 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:32:31] heartbeat #0122 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:33:31] heartbeat #0123 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:34:31] heartbeat #0124 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:35:31] heartbeat #0125 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:36:31] heartbeat #0126 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:37:31] heartbeat #0127 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:38:31] heartbeat #0128 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:39:31] heartbeat #0129 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:40:31] heartbeat #0130 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:41:31] heartbeat #0131 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:42:31] heartbeat #0132 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:43:31] heartbeat #0133 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:44:31] heartbeat #0134 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:45:31] heartbeat #0135 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:46:31] heartbeat #0136 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:47:31] heartbeat #0137 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:48:31] heartbeat #0138 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:49:31] heartbeat #0139 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:50:31] heartbeat #0140 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:51:31] heartbeat #0141 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:52:31] heartbeat #0142 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:53:31] heartbeat #0143 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:54:31] heartbeat #0144 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:55:31] heartbeat #0145 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:56:31] heartbeat #0146 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:57:32] heartbeat #0147 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:58:32] heartbeat #0148 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [18:59:32] heartbeat #0149 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [19:00:32] heartbeat #0150 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [19:01:32] heartbeat #0151 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [19:02:32] heartbeat #0152 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [19:03:32] heartbeat #0153 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [19:04:32] heartbeat #0154 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [19:05:32] heartbeat #0155 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [19:06:32] heartbeat #0156 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [19:07:32] heartbeat #0157 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [19:08:32] heartbeat #0158 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [19:09:32] heartbeat #0159 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [19:10:32] heartbeat #0160 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [19:11:32] heartbeat #0161 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [19:12:32] heartbeat #0162 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [19:13:32] heartbeat #0163 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [19:14:32] heartbeat #0164 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [19:15:32] heartbeat #0165 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [19:16:32] heartbeat #0166 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
#   [19:17:32] heartbeat #0167 | proxy f49a healthy | https://rebates-thinkpad-attached-ate.trycloudflare.com
